# %%
#importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading dataset 

telco_data=pd.read_excel('Telco-Customer-Churn.xlsx')
telco_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # 1. Compare churn count with respect to gender

# %%
telco_data.columns              #To show the column names
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
churn_count=telco_data['Churn'].value_counts()              #to find the total churn count
churn_count
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
sns.countplot(x='Churn',hue='gender',data=telco_data)      # To display the churn count with respect to gender
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# # 2. Find out how many female senior citizens there in the dataset

# %%
fem_dat=telco_data[telco_data['gender']=='Female']    # To fetch all the records of gender female

# %%
female_count=fem_dat.value_counts().sum()  # To show all Female Counts
female_count
# Out:
# 3488

# %%
female_data=telco_data[(telco_data['gender']=='Female') & (telco_data['SeniorCitizen']==1.0)]  # To fetch all records of female
female_data                                                                                  # senior citizens
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 50    8012-SOUDQ  Female            1.0      No         No    43.0
# 52    6575-SUVOI  Female            1.0     Yes         No    25.0
# 53    7495-OOKFY  Female            1.0     Yes         No     8.0
# 54    4667-QONEA  Female            1.0     Yes        Yes    60.0
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female            1.0     Yes         No    50.0
# 7008  1980-KXVPM  Female            1.0      No         No     3.0
# 7010  0723-DRCLG  Female            1.0     Yes         No     1.0
# 7023  1035-IPQPU  Female            1.0     Yes         No    63.0
# 7029  2235-DWLJU  Female            1.0      No         No     6.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
female_data_count=female_data.value_counts().sum()                 # Female senior citizen count
female_data_count
# Out:
# 568

# %%
# To display the count plot of Female Senior citizens

sns.countplot(x=fem_dat['gender'],hue='SeniorCitizen',data=fem_dat,palette=['#6E8B3D',"#FFB90F"])
plt.show()

# %% [markdown]
# # 3. Compare 'tenure' with 'Total Charges'

# %%
# Scatter plot to compare tenure with Total Charges

plt.figure(figsize=(8,6))
plt.scatter(telco_data['tenure'],telco_data['TotalCharges'],s=12,marker='^')
plt.title('Plot of tenure Vs Total Charges',size=16)
plt.xlabel('tenure')
plt.ylabel('Total Charges')
plt.tight_layout()
plt.grid()

# %%
#line plot to compare tenure with Total Charges
sns.lineplot(data=telco_data, x="tenure", y="TotalCharges",color='maroon').set(title='Line Plot of Tenure vs TotalCharges')
# Out:
# [Text(0.5, 1.0, 'Line Plot of Tenure vs TotalCharges')]

# %% [markdown]
# # 4. Find out which contract is preferred by the senior citizen

# %%
#To fetch all the records of Senior Citizens

senior_data=telco_data[telco_data['SeniorCitizen']==1.0]
senior_data.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV    Male            1.0      No         No     1.0           No
# 30  3841-NFECX  Female            1.0     Yes         No    71.0          Yes
# 31  4929-XIHVW    Male            1.0     Yes         No     2.0          Yes
# 34  3413-BMNZE    Male            1.0      No         No     1.0          Yes
# 50  8012-SOUDQ  Female            1.0      No         No    43.0          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 30               Yes     Fiber optic            Yes  ...              Yes
# 31                No     Fiber optic             No  ...              Yes
# 34                No             DSL             No  ...               No
# 50               Yes     Fiber optic             No  ...               No
#
# ...

# %%
# grouping the senior citizen data based on contract

sendat=senior_data.groupby(by=['Contract']).sum()
sendat['SeniorCitizen']
# Out:
# Contract
# Month-to-month    807.0
# One year          190.0
# Two year          145.0
# Name: SeniorCitizen, dtype: float64

# %%
# Pie chart to display which contract is preferred by SeniorCitizen

sendat.plot.pie(y='SeniorCitizen', figsize=(7, 7))
# show plot
plt.legend(title='contract preferred by senior citizens')
plt.show()

# %% [markdown]
# # 5. Comment on your finds on Payment Method

# %% [markdown]
# # 5.1 Pie plot of Payment Method which is popular among SeniorCitizens

# %%
# Data grouped by PaymentMethod

payment_method=telco_data.groupby(by=['PaymentMethod']).sum()
payment_method
# Out:
#                            SeniorCitizen   tenure  MonthlyCharges  \
# PaymentMethod
# Bank transfer (automatic)          233.0  67406.0       103745.45
# Credit card (automatic)            221.0  65856.0       101231.85
# Electronic check                   594.0  59538.0       180345.00
# Mailed check                        94.0  35190.0        70794.30
#
#                            TotalCharges
# PaymentMethod
# Bank transfer (automatic)    4761025.94
# Credit card (automatic)      4680029.60
# Electronic check             4944903.25
# Mailed check                 1746178.00

# %%
#pie plot to display payment method popular among senior citizens

payment_method.plot.pie(y='SeniorCitizen', figsize=(8, 8))
# show plot
plt.legend(title='Payment Method popular among SeniorCitizens')
plt.show()

# %% [markdown]
# # 5.2  Pie plot to display Total charges in Different Payment Methods

# %%
# To display the Pie plot of Total charges in different payment methods

payment_method.plot.pie(y='TotalCharges', figsize=(8, 8))
# show plot
plt.legend(title='TotalCharges in Different Payment Methods')
plt.show()

# %% [markdown]
# # 5.3 Payment Method Prefered by male

# %%
male=telco_data[telco_data['gender']=='Male']  # To fetch all records of gender Male

# %%
# count plot to display the payment method prefered by male
fig, ax = plt.subplots(figsize=(10, 10))
sns.countplot(x=male['gender'],hue='PaymentMethod',data=male,ax=ax).set(title='Payment Method preferred by Male')
# Out:
# [Text(0.5, 1.0, 'Payment Method preferred by Male')]

# %% [markdown]
# # 5.4 Payment Method Prefered by Female

# %%
# count plot to display the payment method prefered by Female

fig, ax = plt.subplots(figsize=(8, 8))
sns.countplot(x=fem_dat['gender'],hue='PaymentMethod',data=fem_dat).set(title='Payment Method prefered by female')
plt.grid()
